# %%
# import libraries
import requests
from bs4 import BeautifulSoup
import urllib
import re
import pandas as pd

# %%
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
import nltk
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))

# %%
MyEmptydf = pd.DataFrame()

# %%
#this function is for getting content of the case
def url_to_string(url):
    res = requests.get(url)
    html = res.text
    soup = BeautifulSoup(html, 'html5lib')
    for script in soup(["script", "style", 'aside']):
        script.extract()
    return " ".join(re.split(r'[\n\t]+', soup.get_text()))

# %%
yearinput = input("Enter a year: ")
# Out:
# Enter a year: 2018

# %%
quote_page = "http://saflii.org/za/cases/ZAWCHC/" + yearinput + "/"

# %%
# query the website and return the html to the variable ‘page’
page = requests.get(quote_page)
# parse the html using beautiful soup and store in variable `soup`
soup = BeautifulSoup(page.content, 'html.parser')
# Take out the <div> of name and get its value
all_a=soup.find('td').find_all('a', attrs={'class': 'make-database'})

# %%
all_url=[]
for a in all_a:
    url="http://saflii.org/za/cases/ZAWCHC"+ a['href'][2:]
    all_url.append(url)

# %%
occupierurl=[]

# %%
for url in all_url:
    page=url_to_string(url)
    if 'Prevention of Illegal Eviction' in page:
        print(url , "has PIE")
        occupierurl.append(url)
if occupierurl == []:
        print('no case about PIE')
# Out:
# http://saflii.org/za/cases/ZAWCHC/2018/40.html has PIE
# http://saflii.org/za/cases/ZAWCHC/2018/185.html has PIE
# http://saflii.org/za/cases/ZAWCHC/2018/158.html has PIE
# http://saflii.org/za/cases/ZAWCHC/2018/169.html has PIE
# http://saflii.org/za/cases/ZAWCHC/2018/126.html has PIE
# http://saflii.org/za/cases/ZAWCHC/2018/143.html has PIE
# http://saflii.org/za/cases/ZAWCHC/2018/138.html has PIE
# http://saflii.org/za/cases/ZAWCHC/2018/137.html has PIE
# http://saflii.org/za/cases/ZAWCHC/2018/167.html has PIE

# %%
mylist = list(set(occupierurl))

# %%
data = {'url':mylist}

# %%
df = pd.DataFrame(data)

# %%
casenumber = []

# %%
#casenumber = []
for url in df['url']:
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')
    title=soup.find('div', attrs={'id': 'squeeze'}).find('h2').get_text()
    title=title.replace('\n    ', '')
    title=title.replace('\n  ', '')
    #print(title)
    casenumber.append(title)
    #print("new for",url)
#casenumber

# %%
df['title']=casenumber

# %%
def hasNumbers(inputString):
    return any(char.isdigit() for char in inputString)

# %%
caseno=[]
judgmentdate=[]

# %%
for s in casenumber:
    var = re.findall('\((.*?)\)',s)
    judgmentdate.append(var[-1])
    var.pop(-1)

# %%
df['judgment date']=judgmentdate

# %%
for s in casenumber:
    var = re.findall('\((.*?)\)',s)
    judgmentdate.append(var[-1])
    var.pop(-1)
    for item in var:
        if hasNumbers(item) == True and len(item) > 3:
            caseno.append(item)
            break;

# %%
df["case number"]=caseno

# %%
erflist = []

# %%
for url in df['url']:
    #print(url)
    #page=urllib.request.urlopen(url).read().decode().lower()
    match = re.search('erf (\d+)', urllib.request.urlopen(url).read().decode().lower())
    if match and len(match.group(1))>2:
        erflist.append(match.group(1))
        #print (match.group(1))
    else:
        erflist.append("not find ERF number")

# %%
df['erf'] = erflist

# %%
hearddate = []

# %%
for url in df['url']:
    print(url)
    ny_bb = url_to_string(url)
    article = str(nlp(ny_bb))
    #page=urllib.request.urlopen(url).read().decode().lower()
    match1 = re.search('hearing: ([^.]+|\S+)', article.lower())
    match2 = re.search('heard: ([^.]+|\S+)', article.lower())
    if match1 and len(match1.group(1))>2:
        #erflist.append(match.group(1))
        text = str(match1.group(1))
        #print(text)
        alldate = re.search(r"((?:\S+\s+){0,2}\b2018)",text)
        print(alldate.group(1))
        hearddate.append(alldate.group(1))
    elif match2 and len(match2.group(1))>2:
        #erflist.append(match.group(1))
        text = str(match2.group(1))
        #print(text)
        alldate = re.search(r"((?:\S+\s+){0,2}\b2018)",text)
        print(alldate.group(1))
        hearddate.append(alldate.group(1))
    
    else:
        hearddate.append("not find heard date")
# Out:
# http://saflii.org/za/cases/ZAWCHC/2018/158.html
# http://saflii.org/za/cases/ZAWCHC/2018/137.html
# http://saflii.org/za/cases/ZAWCHC/2018/126.html
# 20 september 2018
# http://saflii.org/za/cases/ZAWCHC/2018/169.html
# 8 june 2018
# http://saflii.org/za/cases/ZAWCHC/2018/40.html
# 28 february 2018
# http://saflii.org/za/cases/ZAWCHC/2018/138.html
# 12 october 2018
# http://saflii.org/za/cases/ZAWCHC/2018/143.html
# 13 september 2018
# http://saflii.org/za/cases/ZAWCHC/2018/185.html
# http://saflii.org/za/cases/ZAWCHC/2018/167.html

# %%
df['heard date']=hearddate

# %%
caseaddress = []

# %%
for url in df['url']:
    temmatch = []
    page=urllib.request.urlopen(url).read().decode().lower()
    print(url)
    if 'situated' in page:
        print("has situated")
        ny_bb = url_to_string(url)
        article = nlp(ny_bb)
        sentences = [x.text for x in article.sents]
        for senten in sentences:
            if 'situated' in str(senten.lower()):
                match = re.search(r'situated\s+(.*)', str(senten))
                if match and match.group(1).startswith("at") and len(match.group(1))>8:
                    #print(senten)
                    temmatch.append(match.group(1))
                    print(match.group(1))
                elif match and match.group(1).startswith("in") and len(match.group(1))>8:
                    #print(senten)
                    print(match.group(1))
                    temmatch.append(match.group(1))
                elif match and match.group(1).startswith("on") and len(match.group(1))>8:
                    #print(senten)
                    print(match.group(1))
                    temmatch.append(match.group(1))
                    
    if ' road' in page:
        #print(url)
        print( "has road")
        ny_bb = url_to_string(url)
        article = nlp(ny_bb)
        sentences = [x.text for x in article.sents]
        for senten in sentences:
            if ' road' in str(senten.lower()):
                match = re.search(r"((?:\S+\s+){0,1}\broad)",str(senten.lower()))
                if not match.group(1).split(' ', 1)[0] in stop_words:
                    #print(senten)
                    print(match.group(1))
                    temmatch.append(match.group(1))
                
    if ' street' in page:
        #print(url)
        print( "has street")
        ny_bb = url_to_string(url)
        article = nlp(ny_bb)
        sentences = [x.text for x in article.sents]
        for senten in sentences:
            if ' street' in str(senten.lower()):
                match = re.search(r"((?:\S+\s+){0,1}\bstreet)",str(senten.lower()))
                if not match.group(1).split(' ', 1)[0] in stop_words:
                    #print(senten)
                    print(match.group(1))
                    temmatch.append(match.group(1))
                    
    if ' avenue' in page:
        #print(url)
        print( "has Avenue")
        ny_bb = url_to_string(url)
        article = nlp(ny_bb)
        sentences = [x.text for x in article.sents]
        for senten in sentences:
            if ' avenue' in str(senten.lower()):
                match = re.search(r"((?:\S+\s+){0,1}\bavenue)",str(senten.lower()))
                if not match.group(1).split(' ', 1)[0] in stop_words:
                    #print(senten)
                    print(match.group(1))
                    temmatch.append(match.group(1))
    if temmatch:
        caseaddress.append(temmatch[0])
    if not temmatch:
        caseaddress.append("not find address")
# Out:
# http://saflii.org/za/cases/ZAWCHC/2018/158.html
# has situated
# has road
# http://saflii.org/za/cases/ZAWCHC/2018/137.html
# has street
# leeuwen street
# http://saflii.org/za/cases/ZAWCHC/2018/126.html
# has situated
# on the (City owned)
# has road
# adjacent road
# http://saflii.org/za/cases/ZAWCHC/2018/169.html
# has road
# broad road
# broad road
# has street
# http://saflii.org/za/cases/ZAWCHC/2018/40.html
# has situated
# has road
# hendon road
# has street
# http://saflii.org/za/cases/ZAWCHC/2018/138.html
# has street
# http://saflii.org/za/cases/ZAWCHC/2018/143.html
# has street
# http://saflii.org/za/cases/ZAWCHC/2018/185.html
# has situated
# at Erf […], Maasdorp, La Motte, Franschhoek (‘the eviction order’).
# http://saflii.org/za/cases/ZAWCHC/2018/167.html
# has situated
# at erf 235, Stellenbosch on or before 1 March 2019.

# %%
df['address'] = caseaddress

# %%
df['year'] = yearinput

# %%
MyEmptydf=MyEmptydf.append(df)

# %%
MyEmptydf
# Out:
#                                                 url  \
# 0     http://saflii.org/za/cases/ZAWCHC/1999/1.html
# 1     http://saflii.org/za/cases/ZAWCHC/1999/2.html
# 0    http://saflii.org/za/cases/ZAWCHC/2003/48.html
# 1    http://saflii.org/za/cases/ZAWCHC/2003/26.html
# 2    http://saflii.org/za/cases/ZAWCHC/2003/71.html
# 3    http://saflii.org/za/cases/ZAWCHC/2003/15.html
# 0     http://saflii.org/za/cases/ZAWCHC/2004/5.html
# 1    http://saflii.org/za/cases/ZAWCHC/2004/51.html
# 0    http://saflii.org/za/cases/ZAWCHC/2005/16.html
# 0    http://saflii.org/za/cases/ZAWCHC/2006/50.html
# 1    http://saflii.org/za/cases/ZAWCHC/2006/70.html
# 2    http://saflii.org/za/cases/ZAWCHC/2006/62.html
# 0    http://saflii.org/za/cases/ZAWCHC/2007/20.html
# 0    http://saflii.org/za/cases/ZAWCHC/2008/14.html
# 1    http://saflii.org/za/cases/ZAWCHC/2008/15.html
# 2    http://saflii.org/za/cases/ZAWCHC/2008/43.html
# 3   http://saflii.org/za/cases/ZAWCHC/2008/305.html
# 0   http://saflii.org/za/cases/ZAWCHC/2009/228.html
# 1   http://saflii.org/za/cases/ZAWCHC/2009/189.html
# 0    http://saflii.org/za/cases/ZAWCHC/2010/41.html
# 1   http://saflii.org/za/cases/ZAWCHC/2010/128.html
# 2    http://saflii.org/za/cases/ZAWCHC/2010/91.html
# 3   http://saflii.org/za/cases/ZAWCHC/2010/176.html
# 4   http://saflii.org/za/cases/ZAWCHC/2010/365.html
# 5    http://saflii.org/za/cases/ZAWCHC/2010/46.html
# 0    http://saflii.org/za/cases/ZAWCHC/2011/19.html
# 1   http://saflii.org/za/cases/ZAWCHC/2011/331.html
# 2   http://saflii.org/za/cases/ZAWCHC/2011/238.html
# 3   http://saflii.org/za/cases/ZAWCHC/2011/305.html
# 4   http://saflii.org/za/cases/ZAWCHC/2011/450.html
# ..                                              ...
# 1   http://saflii.org/za/cases/ZAWCHC/2014/138.html
# 2    http://saflii.org/za/cases/ZAWCHC/2014/28.html
# 3   http://saflii.org/za/cases/ZAWCHC/2014/193.html
# 4    http://saflii.org/za/cases/ZAWCHC/2014/32.html
# 5    http://saflii.org/za/cases/ZAWCHC/2014/60.html
# 0    http://saflii.org/za/cases/ZAWCHC/2015/97.html
# 1   http://saflii.org/za/cases/ZAWCHC/2015/202.html
# 2    http://saflii.org/za/cases/ZAWCHC/2015/58.html
# 0   http://saflii.org/za/cases/ZAWCHC/2016/133.html
# 1   http://saflii.org/za/cases/ZAWCHC/2016/168.html
# 2    http://saflii.org/za/cases/ZAWCHC/2016/33.html
# 3   http://saflii.org/za/cases/ZAWCHC/2016/167.html
# 4    http://saflii.org/za/cases/ZAWCHC/2016/68.html
# 0   http://saflii.org/za/cases/ZAWCHC/2017/116.html
# 1   http://saflii.org/za/cases/ZAWCHC/2017/126.html
# 2    http://saflii.org/za/cases/ZAWCHC/2017/73.html
# 3   http://saflii.org/za/cases/ZAWCHC/2017/117.html
# 4    http://saflii.org/za/cases/ZAWCHC/2017/80.html
# 5    http://saflii.org/za/cases/ZAWCHC/2017/14.html
# 6    http://saflii.org/za/cases/ZAWCHC/2017/24.html
# 7   http://saflii.org/za/cases/ZAWCHC/2017/142.html
# 0   http://saflii.org/za/cases/ZAWCHC/2018/158.html
# 1   http://saflii.org/za/cases/ZAWCHC/2018/137.html
# 2   http://saflii.org/za/cases/ZAWCHC/2018/126.html
# 3   http://saflii.org/za/cases/ZAWCHC/2018/169.html
# 4    http://saflii.org/za/cases/ZAWCHC/2018/40.html
# 5   http://saflii.org/za/cases/ZAWCHC/2018/138.html
# 6   http://saflii.org/za/cases/ZAWCHC/2018/143.html
# 7   http://saflii.org/za/cases/ZAWCHC/2018/185.html
# 8   http://saflii.org/za/cases/ZAWCHC/2018/167.html
#
#                                                 title      judgment date  \
# 0   Grootboom and Others v Oostenberg Municipality...   17 December 1999
# 1   Ross v South Peninsula Municipality (A741/98) ...   3 September 1999
# 0   Absa Bank bpk v Murray and Another (8946/02) [...  18 September 2003
# 1   Jaftha v Schoeman and Others (8617/01) [2003] ...       25 June 2003
# 2   Nduna v Absa Bank Ltd and Others (4596/03) [20...   12 December 2003
# 3   City of Cape Town v Persons who are presently ...        20 May 2003
# 0   City of Cape Town v Yawa and Others (395/04) [...    29 January 2004
# 1   City of Cape Town v Yawa and Others (395/04) [...    29 January 2004
# 0   Davids and Others v Van Straaten and Others (9...      17 March 2005
# 0   Laskey and Another v Showzone CC and Others (5...    30 October 2006
# 7          A325/2016; A326/2016  not find ERF number     17 february 2017
# 0                      A55/2018  not find ERF number  not find heard date
# 1                    15217/2018  not find ERF number  not find heard date
# 2                    16420/2018                39371    20 september 2018
# 3                      A99/2018  not find ERF number          8 june 2018
# 4                    14639/2017  not find ERF number     28 february 2018
# 5                      23256/17  not find ERF number      12 october 2018
# 6                     3860/2016  not find ERF number    13 september 2018
# 7                        A85/18  not find ERF number  not find heard date
# 8                     4467/2018                  235  not find heard date
#
#                                               address  year
# 0                                    not find address  1999
# 1                                    not find address  1999
# 0                                    not find address  2003
# 1                                    not find address  2003
# 2                                       zodiac street  2003
# 3                                      adjoining road  2003
# 0                                    not find address  2004
# 1                                    not find address  2004
# 0                                        leeuwen road  2005
# 0   initially at an address in Green Point, but in...  2006
# 1                                    not find address  2006
# 2                  at 6 Kroneberg Street, Wellington.  2006
# 0                                    not find address  2007
# 0                                       arterial road  2008
# 1   in precincts 4 and 6 of Delft Symphony, to vac...  2008
# 2                                         stel street  2008
# 3                                    not find address  2008
# 0                                         olivia road  2009
# 1                                    not find address  2009
# 0   on a site with electricity, water and sanitation.  2010
# 1                                       mapolo street  2010
# 2   in a small section of District Six on the west...  2010
# 3                                       strand street  2010
# 4   in George known as erven 457 and 458 in the Th...  2010
# 5                                    not find address  2010
# 0     at 27 Eloff Street, Portlands Mitchell's Plain.  2011
# 1   at, and commonly known as, 19 Church Street, H...  2011
# 2                                    not find address  2011
# 3                                    not find address  2011
# 4   on both the applicant's property and ACSA's pr...  2011
# ..                                                ...   ...
# 1                                    not find address  2014
# 2                                    not find address  2014
# 3   on Applethwaite Farm, Grabouw, Western Cape in...  2014
# 4                                    not find address  2014
# 5                                       bamboo street  2014
# 0   in Khayelitsha, known as Erf 52676, Khayelitsh...  2015
# 1                                        olivier road  2015
# 2                                         hendon road  2015
# 0   in Kraaifontein near the City’s border with th...  2016
# 1           at 46 Woodley Road, Plumstead, Cape Town.  2016
# 2                                  shortmarket street  2016
# 3               at 1 Stratford Avenue Eerste River.    2016
# 4                                    not find address  2016
# 0   at the Blaauwberg Nature Reserve (“the reserve...  2017
# 1   at[…], Plantation Street, Ceres, Western Cape ...  2017
# 2                                    not find address  2017
# 3                                     malmesbury road  2017
# 4                                           b. street  2017
# 5                                          new street  2017
# 6   at […], S. Crescent, Ruyterwacht, Western Cape...  2017
# 7                                    not find address  2017
# 0                                    not find address  2018
# 1                                      leeuwen street  2018
# 2                                 on the (City owned)  2018
# 3                                          broad road  2018
# 4                                         hendon road  2018
# 5                                    not find address  2018
# 6                                    not find address  2018
# 7   at Erf […], Maasdorp, La Motte, Franschhoek (‘...  2018
# 8   at erf 235, Stellenbosch on or before 1 March ...  2018
#
# [81 rows x 8 columns]

# %%
with pd.ExcelWriter(r'C:\Users\yyjia\Desktop\sjcdata\pie.xlsx') as writer:
    MyEmptydf.to_excel(writer, index = None, header=True)
